# %% [markdown]
# ## Enchanced Super Resolution GAN validation procedures

# %%
import torch
from PIL import Image
import os
import numpy as np
from torchvision.utils import save_image
from tqdm import tqdm
import matplotlib.pyplot as plt

import torchvision.transforms as tt
import gc

from ESRGAN.model import *

MODEL_PATH = "ESRGAN"
LR_PATH = "DIV2K_valid_LR_bicubic/X4"
HR_PATH = "DIV2K_valid_HR"

CHECKPOINT_GEN = "gen_esrgan.pth"
#LR_PATH = "test_images"
RESULT_IMAGES = "result_images"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Download low-res validation dataset
#!wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X4.zip
#!unzip DIV2K_valid_LR_bicubic_X4.zip

# %%
# Download high-res validation dataset
#!wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
#!unzip DIV2K_valid_HR.zip

# %%
# Test image transformation
test_transform = tt.Compose(
    [
        tt.ToTensor(),
        tt.Normalize(mean=[0, 0, 0], std=[1, 1, 1])
    ]
)

# %%
# PSNR loss function
def psnr_loss(upscaled_img, valid_img):
        psnr = 10. * torch.log10(1. / torch.mean((upscaled_img - valid_img) ** 2))
        return psnr.item()

# %%
# Load pre-trained model state
def load_model(filename, model):
    filename = os.path.join(MODEL_PATH, filename)
    print("=> Loading model from " + filename)
    checkpoint = torch.load(filename, map_location=DEVICE)
    model.load_state_dict(checkpoint["state_dict"])

# %%
# Reading low-res images and convert them into high-res images 
def plot_examples(gen):
    # For all files in low-res folder
    files = os.listdir(LR_PATH)
    total_psnr = []
    total_files = []

    gen.eval()
    loop = tqdm(files, leave=True)
    for file in loop:
        psnr = 0.
        image = Image.open(os.path.join(LR_PATH, file))
        
        with torch.no_grad():
            upscaled_img = gen(test_transform(image).unsqueeze(0).to(DEVICE))
            upscaled_img = upscaled_img.detach().to('cpu')
        # Save reconstructed image to disk
        fname, fext = os.path.splitext(file)
        fname = fname.replace('x4', 'u4')
        save_image(upscaled_img, os.path.join(RESULT_IMAGES, fname + fext))

        # Trying to find validation hi-res image for an upscaled low-res image
        fname = fname.replace('u4', '')
        valid_file = os.path.join(HR_PATH, fname + fext)
        # Calculating PSNR for validation and reconstructed images
        if os.path.exists(valid_file):
            image = Image.open(valid_file)
            valid_img = test_transform(image)
            psnr = psnr_loss(upscaled_img.squeeze(0), valid_img)
        loop.set_postfix(file=file, psnr=psnr)
        total_psnr.append(psnr)
        total_files.append(file)
    return total_files, total_psnr

# %%
def main():
    
    # Loading the pre-trained image generator
    gen = Generator(in_channels=3).to(DEVICE)
    load_model(CHECKPOINT_GEN, gen)

    total_files, total_psnr = plot_examples(gen)
    print('PSNR per files')
    # Processing low-res images
    for i in range(len(total_files)):
        print(f'File name = {total_files[i]}, PSNR = {total_psnr[i]:.2f}')
    
    mean_psnr = np.array(total_psnr).mean()
    print(f'Mean PSNR for all files = {mean_psnr:.4f}')
    # Show PSNR
    plt.figure(figsize=(15, 6))
    plt.bar(range(len(np.array(total_psnr))), np.array(total_psnr))
    plt.xlabel('file number')
    plt.ylabel('psnr')
    plt.title('PSNR metric for files')
    plt.show()

    del(gen)

main()
# Out:
# => Loading model from ESRGAN\gen_esrgan.pth
# 100%|██████████| 100/100 [04:49<00:00,  2.89s/it, file=0900x4.png, psnr=24.8]
# PSNR per files
# File name = 0801x4.png, PSNR = 27.92
# File name = 0802x4.png, PSNR = 31.88
# File name = 0803x4.png, PSNR = 32.56
# File name = 0804x4.png, PSNR = 25.63
# File name = 0805x4.png, PSNR = 27.48
# File name = 0806x4.png, PSNR = 26.54
# File name = 0807x4.png, PSNR = 19.44
# File name = 0808x4.png, PSNR = 25.62
# File name = 0809x4.png, PSNR = 30.46
# File name = 0810x4.png, PSNR = 25.82
# File name = 0811x4.png, PSNR = 27.99
# File name = 0812x4.png, PSNR = 26.05
# File name = 0813x4.png, PSNR = 28.85
# File name = 0814x4.png, PSNR = 26.56
# File name = 0815x4.png, PSNR = 31.41
# File name = 0816x4.png, PSNR = 29.71
# File name = 0817x4.png, PSNR = 29.59
# File name = 0818x4.png, PSNR = 26.85
# File name = 0819x4.png, PSNR = 26.62
# File name = 0820x4.png, PSNR = 22.07
# File name = 0821x4.png, PSNR = 26.42
# File name = 0822x4.png, PSNR = 28.57
# File name = 0823x4.png, PSNR = 24.67
# File name = 0824x4.png, PSNR = 25.81
# File name = 0825x4.png, PSNR = 25.19
# File name = 0826x4.png, PSNR = 23.18
# File name = 0827x4.png, PSNR = 30.85
# File name = 0828x4.png, PSNR = 17.11
# File name = 0829x4.png, PSNR = 25.89
# File name = 0830x4.png, PSNR = 23.50
# File name = 0831x4.png, PSNR = 27.49
# File name = 0832x4.png, PSNR = 28.13
# File name = 0833x4.png, PSNR = 29.97
# File name = 0834x4.png, PSNR = 24.48
# File name = 0835x4.png, PSNR = 22.20
# File name = 0836x4.png, PSNR = 23.59
# File name = 0837x4.png, PSNR = 24.35
# File name = 0838x4.png, PSNR = 34.35
# File name = 0839x4.png, PSNR = 28.20
# File name = 0840x4.png, PSNR = 27.25
# File name = 0841x4.png, PSNR = 26.68
# File name = 0842x4.png, PSNR = 28.32
# File name = 0843x4.png, PSNR = 36.85
# File name = 0844x4.png, PSNR = 35.50
# File name = 0845x4.png, PSNR = 22.00
# File name = 0846x4.png, PSNR = 21.96
# File name = 0847x4.png, PSNR = 25.63
# File name = 0848x4.png, PSNR = 25.32
# File name = 0849x4.png, PSNR = 20.20
# File name = 0850x4.png, PSNR = 27.06
# File name = 0851x4.png, PSNR = 26.75
# File name = 0852x4.png, PSNR = 28.92
# File name = 0853x4.png, PSNR = 31.00
# File name = 0854x4.png, PSNR = 23.75
# File name = 0855x4.png, PSNR = 27.95
# File name = 0856x4.png, PSNR = 23.28
# File name = 0857x4.png, PSNR = 32.36
# File name = 0858x4.png, PSNR = 27.18
# File name = 0859x4.png, PSNR = 24.33
# File name = 0860x4.png, PSNR = 19.79
# File name = 0861x4.png, PSNR = 21.56
# File name = 0862x4.png, PSNR = 31.59
# File name = 0863x4.png, PSNR = 31.15
# File name = 0864x4.png, PSNR = 28.87
# File name = 0865x4.png, PSNR = 26.41
# File name = 0866x4.png, PSNR = 24.24
# File name = 0867x4.png, PSNR = 26.57
# File name = 0868x4.png, PSNR = 29.46
# File name = 0869x4.png, PSNR = 22.85
# File name = 0870x4.png, PSNR = 27.20
# File name = 0871x4.png, PSNR = 29.63
# File name = 0872x4.png, PSNR = 22.77
# File name = 0873x4.png, PSNR = 22.96
# File name = 0874x4.png, PSNR = 28.38
# File name = 0875x4.png, PSNR = 22.87
# File name = 0876x4.png, PSNR = 21.44
# File name = 0877x4.png, PSNR = 35.67
# File name = 0878x4.png, PSNR = 29.32
# File name = 0879x4.png, PSNR = 25.71
# File name = 0880x4.png, PSNR = 30.49
# File name = 0881x4.png, PSNR = 25.00
# File name = 0882x4.png, PSNR = 30.96
# File name = 0883x4.png, PSNR = 25.23
# File name = 0884x4.png, PSNR = 24.52
# File name = 0885x4.png, PSNR = 21.96
# File name = 0886x4.png, PSNR = 32.52
# File name = 0887x4.png, PSNR = 23.47
# File name = 0888x4.png, PSNR = 28.04
# File name = 0889x4.png, PSNR = 27.88
# File name = 0890x4.png, PSNR = 24.65
# File name = 0891x4.png, PSNR = 24.36
# File name = 0892x4.png, PSNR = 26.25
# File name = 0893x4.png, PSNR = 31.12
# File name = 0894x4.png, PSNR = 29.21
# File name = 0895x4.png, PSNR = 19.81
# File name = 0896x4.png, PSNR = 32.85
# File name = 0897x4.png, PSNR = 20.86
# File name = 0898x4.png, PSNR = 31.71
# File name = 0899x4.png, PSNR = 26.91
# File name = 0900x4.png, PSNR = 24.75
# Mean PSNR for all files = 26.7632

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
###############################
